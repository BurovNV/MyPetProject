# %%
# импорт
import requests, base64, datetime, time, json
from urllib.parse import urlencode

import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rrp.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
import django
django.setup()
from tracks.models import *

# %%
# переменные для авторизации Spotify
CLIENT_ID      = 'ddd7b7ba65814c03afa810d062635ae2'
CLIENT_SECRET  = '62b9dd2f26fd47e8ad07e4274fc441f6'
# данные для авторизации Last FM
API_KEY        = '5a0ae1296c8d4388a66c507ba27e92aa'

# %%
# подключение к API и прочие сервисные функции, взято на
# "https://github.com/codingforentrepreneurs/30-Days-of-Python/tree/master/tutorial-reference/Day%2019"
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id     = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id     = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in   = data['expires_in'] # seconds
        expires      = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

# %%
# обновить или создать токен
def get_token(client_id, client_secret):
    spotify = SpotifyAPI(client_id, client_secret)
    spotify.perform_auth()
    access_token = spotify.access_token
    return access_token

# %%
# список групп для поиска
bands = []
with open('bands.txt', encoding='UTF-8') as f:
    for line in f.readlines():
        bands.append(line.strip())

# %%
# заполнение таблицы 'Band'
def populate_bands(bands, client_id, client_secret):
    '''
    Функция проходит по всему списку групп и парсит для
    каждой инфу с сайта Spotify.
    Необходимо передать client_id и client_secret для вызова.
    Заполняет поля:    
    
        band_id         : id группы на Spotify,
        band_name       : название,
        band_genres     : список жанров, определенных для группы,
        band_URL        : ссылка на группу,
        band_followers  : кол-во подписчиков,
        band_popularity : индекс популярности (0-100),
        band_image_300  : ссылка на изображение 300 * 300,
        band_image_64   : ссылка на изображение 64 * 64
    '''
    # обновить или создать токен
    access_token = get_token(client_id, client_secret)

    # поиск групп из списка
    # GET "https://api.spotify.com/v1/search?q=some_name&type=artist"
    for band in bands:
        time.sleep(1)
        # вывод логов
        print(f'Поиcк группы "{band}" ...')

        headers = {"Authorization": f"Bearer {access_token}"}
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": f'"{band}"', "type": "artist"})
        lookup_url = f"{endpoint}?{data}"
        request = requests.get(lookup_url, headers=headers).json()

        # обход групп в результате запроса
        artists = request['artists']['items']
        for index, artist in enumerate(artists):
            # сбор всех жанров группы
            genres = ', '.join(request['artists']['items'][index]['genres'])
            # если жанры содержат "russian" - спарсить данные
            if (genres.__contains__ ('russian')) and not \
               (genres.__contains__ ('piano') or genres.__contains__ ('dnb')):
                # вывод логов
                print(f'Найдено совпадение для "{band}" - {artist["name"]}')
                band_dict = { 
                    'band_id'         : artist['id'],
                    'band_name'       : band,
                    'band_genres'     : genres,
                    'band_URL'        : artist['external_urls']['spotify'],
                    'band_followers'  : artist['followers']['total'],
                    'band_popularity' : artist['popularity'],
                    'band_image_300'  : artist['images'][1]['url'],
                    'band_image_64'   : artist['images'][2]['url']
                }
                # первое совпадение - искомая группа
                # создание записи в БД
                Band.objects.create(**band_dict)
                # не запрашивать жанры других групп
                break
    # вывод логов
    print(f'Поиск завершен, найдено групп - {len(Band.objects.all())}')

# populate_bands(bands=bands, client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

# %%
# заполнение таблицы 'Album'
def populate_albums(client_id, client_secret):
    '''
    Функция проходит по всему списку альбомов в БД и парсит для
    каждого инфу с сайта Spotify.
    Необходимо передать client_id и client_secret для вызова.
    Заполняет поля:    

        band_id            : id группы на Spotify,    
        band_name          : название группы,
        album_id           : id альбома на Spotify,
        album_name         : название альбома,
        album_type_1       : тип альбома 1,
        album_type_2       : тип альбома 2,
        album_URL          : ссылка на альбом,
        album_release_date : дата выхода,
        album_total_tracks : кол-во треков в альбоме,
        album_image_300    : ссылка на изображение 300 * 300,
        album_image_64     : ссылка на изображение 64 * 64

    '''
    # обновить или создать токен
    access_token = get_token(client_id, client_secret)

    # получение списка альбомов из БД
    bands = Band.objects.all().values_list('band_name', 'band_id', 
                                           'band_image_300', 'band_image_64')
    # создание списка спарсенных альбомов
    albums_ids = []
    # обход альбомов и создание временных переменных
    for band in bands:
        band_name      = band[0]
        band_id        = band[1]
        band_image_300 = band[2]
        band_image_64  = band[3]

        # запрос к Spotify 
        # GET https://api.spotify.com/v1/artists/{id}/albums
        print(f'Поиск альбомов группы "{band_name}" ...')
        # time.sleep(1)
        album_headers    = {"Authorization": f"Bearer {access_token}"}
        album_endpoint   = "https://api.spotify.com/v1/artists/"
        album_lookup_url = f"{album_endpoint}{band_id}/albums"
        album_request    = requests.get(album_lookup_url, headers=album_headers).json()

        # проход в цикле по альбомам в результате запроса
        albums = album_request['items']
        for album in albums:
            #  если нет картинки альбома - взять картинку группы
            try:            
                album_image_300 = album['images'][0]['url']
            except:
                album_image_300 = band_image_300
            try:            
                album_image_64  = album['images'][1]['url']
            except:
                album_image_64  = band_image_64
            # если в дате ошибка - считать год и дописать 01.01
            album_release_date = album['release_date']
            if len(album_release_date) < 10:
                album_release_date = f'{album_release_date[:4]}-01-01'
            # проверка на дублирование альбома
            if album['id'] in albums_ids:
                continue
            else:
                # словарь с данными для создания записи в БД
                album_dict = {
                    'album_id'           : album['id'],
                    'album_name'         : album['name'],
                    'album_type_1'       : album['album_group'],
                    'album_type_2'       : album['album_group'],
                    'album_URL'          : album['external_urls']['spotify'],
                    'album_release_date' : album_release_date,
                    'album_total_tracks' : album['total_tracks'],
                    'album_image_300'    : album_image_300,
                    'album_image_64'     : album_image_64,
                    'band_name'          : band_name,
                    'band_id'            : Band.objects.get(band_id=band_id)
                }
                # внести ID альбома в список спарсенных
                albums_ids.append(album['id'])
                # создание записи в БД
                Album.objects.create(**album_dict)
                # вывод логов
                album_name = album['name']
                print(f'--- Найден альбом "{album_name}"')
    # вывод логов
    print(f'Поиск завершен, найдено альбомов - {len(Album.objects.all())}')
    # удалить список спарсенных альбомов
    del albums_ids

# populate_albums(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

# %%
# удаление треков с ошибками
def del_fail_album(start):
    album_to_del = Album.objects.all().order_by('album_id').values_list('album_id')[start][0]
    Track.objects.filter(album_id=album_to_del).delete()

# заполнение таблицы 'Track'
def populate_tracks(client_id, client_secret, start):
    '''
    Функция проходит по всему списку треков в БД и парсит для
    каждого инфу с сайта Spotify + кол-во прослушиваний с Last FM 
    Необходимо передать client_id и client_secret для вызова.
    В случае сбоя - удалить треки из альбома номер которого выведен в логах
    последним и вызвать функцию с параметром "start" равным номеру этого альбома
    Заполняет поля:

        --- общие свойства ---
        band_id           : id группы на Spotify, 
        band_name         : название группы,
        album_id          : id альбома на Spotify,
        album_name        : название альбома,
        track_id          : id трека на Spotify,
        track_name        : название трека,
        track_disc_number : номер диска в альбоме,
        track_number      : номер трека на диске,
        track_duration    : длительность трека в мс,
        track_image_300   : ссылка на изображение 300 * 300, 
        track_image_64    : ссылка на изображение 64 * 64,
        track_preview     : отрывок из трека 30 секунд,
        track_URL         : ссылка на трек

        --- аудио свойства трека ---
        track_danceability    : 
        track_energy          : 
        track_key             : 
        track_loudness        : 
        track_mode            : 
        track_speechiness     : 
        track_acousticness    : 
        track_instrumentalness: 
        track_liveness        : 
        track_valence         : 
        track_tempo           : 

        --- кол-во прослушиваний с Last FM ---
        track_listeners: прослушано до конца,
        track_playcount: прослушано частично 

    '''
    # обновить или создать токен
    access_token = get_token(client_id, client_secret)

    # получение треков для каждого альбома
    albums = Album.objects.all().values_list('band_name', 'band_id', 
                                             'album_name', 'album_id',
                                             'album_image_300', 'album_image_64') \
                                             .order_by('album_id')

    # проход по всем альбомам в цикле while - 
    # попытка спарсить все треки и всею инфу по каждому треку
    # если ошибка - удаление всех треков альбома и повтор
    start  = start
    finish = len(albums)

    while start < finish:
        try:
            album = albums[start]
            # создание временных переменных
            band_name       = album[0]  # 'Ленинград'
            band_id         = album[1]  # '2a3EJeQjcAelthFGr5bzQC' 
            album_name      = album[2]  # 'Пуля'
            album_id        = album[3]  # '00QHUtm8MHpeoYHiqXRhX6'
            album_image_300 = album[4]  # 'https://i.scdn.co/image/ab.....'
            album_image_64  = album[5]  # 'https://i.scdn.co/image/ab.....'

            # запрос к Spotify
            #  GET https://api.spotify.com/v1/albums/{id}/tracks
            time.sleep(1)  
            track_headers = {"Authorization": f"Bearer {access_token}"}
            track_endpoint = "https://api.spotify.com/v1/albums/"
            track_lookup_url = f"{track_endpoint}{album_id}/tracks"
            track_request = requests.get(track_lookup_url, headers=track_headers).json()
            # вывод логов
            print(f'Поиск треков из {start} альбома "{band_name}" - "{album_name}"')

            # обход треков в результате запроса
            tracks_by_album = track_request['items']
            for track in tracks_by_album:
                
                track_name = track['name']
                track_id   = track['id']
                # если нет ссылки на превью - взять дефолт
                if track['preview_url']:
                    track_preview = track['preview_url']
                # либо продолжить по плану   
                else:
                    # логи
                    print(f'--- !!! Preview трека "{band_name}" - "{track_name}" не найдено')
                    track_preview = Track.objects.all().values_list('track_preview')[0][0]
                # вывод логов
                print(f'--- Найден трек  "{track_name}"')
                # словарь с общими данными трека
                track_info = {
                    'track_id'          : track['id'],
                    'track_name'        : track['name'],
                    'track_disc_number' : track['disc_number'],
                    'track_number'      : track['track_number'],
                    'track_duration'    : track['duration_ms'],
                    'album_id'          : Album.objects.get(album_id=album_id),
                    'album_name'        : album_name,
                    'band_id'           : Band.objects.get(band_id=band_id), 
                    'band_name'         : band_name,
                    'track_image_300'   : album_image_300, 
                    'track_image_64'    : album_image_64,
                    'track_preview'     : track_preview,
                    'track_URL'         : track['external_urls']['spotify']
                }
                
                # получение аудио фичей из Spotify
                # GET https://api.spotify.com/v1/audio-features/{id}
                time.sleep(1)
                # логи
                print(f'--- Поиск аудио фичей для трека "{band_name}" - "{track_name}"')
                
                feautures_headers    = {"Authorization": f"Bearer {access_token}"}
                feautures_endpoint   = "https://api.spotify.com/v1/audio-features/"
                feautures_lookup_url = f"{feautures_endpoint}{track_id}"
                feautures_request    = requests.get(feautures_lookup_url, headers=feautures_headers).json()

                # если нет записей - пропустить (в БД для всех фичей дефолт = 0.)
                try:       
                    track_audio_features = {
                        'track_danceability'    : feautures_request['danceability'],
                        'track_energy'          : feautures_request['energy'],
                        'track_key'             : feautures_request['key'],
                        'track_loudness'        : feautures_request['loudness'],
                        'track_mode'            : feautures_request['mode'],
                        'track_speechiness'     : feautures_request['speechiness'],
                        'track_acousticness'    : feautures_request['acousticness'],
                        'track_instrumentalness': feautures_request['instrumentalness'],
                        'track_liveness'        : feautures_request['liveness'],
                        'track_valence'         : feautures_request['valence'],
                        'track_tempo'           : feautures_request['tempo'],
                    }
                    track_info.update(track_audio_features)
                    # логи
                    print(f'--- Аудио фичи для трека "{band_name}" - "{track_name}" найдены')
                except:
                    # логи
                    print(f'--- !!! Аудио фичи для трека "{band_name}" - "{track_name}" не найдены')


                # получение данных о прослушивании трека на Last FM
                # GET http://ws.audioscrobbler.com/2.0/?method=track.getInfo&api_key={API_KEY}
                # &artist={ARTIST_NAME}&track={TRACK_NAME}&format=json
                # вывод логов
                print(f'--- Поиск информации о прослушиваниях "{band_name}" - "{track_name}"')
                time.sleep(5)
                try:
                    lastFM_endpoint   = "http://ws.audioscrobbler.com/2.0/?method=track.getInfo&api_key="
                    lastFM_lookup_url = f"{lastFM_endpoint}{API_KEY}&artist={band_name}&track={track_name}&format=json"
                    lastFM_request   = requests.get(lastFM_lookup_url).json()

                    last_fm_features = {
                        'track_listeners': lastFM_request['track']['listeners'],
                        'track_playcount': lastFM_request['track']['playcount'] 
                    }

                    track_info.update(last_fm_features)
                    # вывод логов
                    print(f'--- Информация о прослушиваниях "{band_name}" - "{track_name}" добавлена')
                except:
                    # вывод логов
                    print(f'--- !!! Информация о прослушиваниях "{band_name}" - "{track_name}" не найдена')
                    pass

                # создание записи в БД
                Track.objects.create(**track_info)
                # вывод логов
                print(f'--- Добавлен трек  "{track_name}"')

            start += 1

        except:
            # вывод логов
            print(f'!!! Повторная загрузка информации об альбоме "{band_name}" - "{album_name}"')
            # обновить или создать токен
            access_token = get_token(client_id, client_secret)
            # в случае ошибки - удалить все трекит текущего альбома
            # и начать парсинг этого альбома сначала
            Track.objects.filter(album_id=album_id).delete()

    # финальные логи
    print(f'Добавлено {len(Track.objects.all())} треков')

# при ошибке парсинга установить значение "start" из логов
# при первом запуске не менять  
START = 0
del_fail_album(START)

# populate_tracks(client_id=CLIENT_ID, client_secret=CLIENT_SECRET, start=START)
# Out:
# Поиск треков из 2060 альбома "Полюса" - "Точка невозврата (Remastered)"
# --- Найден трек  "Кино - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Кино - Remastered"
# --- Аудио фичи для трека "Полюса" - "Кино - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Кино - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Кино - Remastered" добавлена
# --- Добавлен трек  "Кино - Remastered"
# --- Найден трек  "Витки - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Витки - Remastered"
# --- Аудио фичи для трека "Полюса" - "Витки - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Витки - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Витки - Remastered" добавлена
# --- Добавлен трек  "Витки - Remastered"
# --- Найден трек  "Делай меня живым - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Делай меня живым - Remastered"
# --- Аудио фичи для трека "Полюса" - "Делай меня живым - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Делай меня живым - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Делай меня живым - Remastered" добавлена
# --- Добавлен трек  "Делай меня живым - Remastered"
# --- Найден трек  "На спине у кита - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "На спине у кита - Remastered"
# --- Аудио фичи для трека "Полюса" - "На спине у кита - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "На спине у кита - Remastered"
# --- Информация о прослушиваниях "Полюса" - "На спине у кита - Remastered" добавлена
# --- Добавлен трек  "На спине у кита - Remastered"
# --- Найден трек  "Мне нужен робот - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Мне нужен робот - Remastered"
# --- Аудио фичи для трека "Полюса" - "Мне нужен робот - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Мне нужен робот - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Мне нужен робот - Remastered" добавлена
# --- Добавлен трек  "Мне нужен робот - Remastered"
# --- Найден трек  "Безразмерная - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Безразмерная - Remastered"
# --- Аудио фичи для трека "Полюса" - "Безразмерная - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Безразмерная - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Безразмерная - Remastered" добавлена
# --- Добавлен трек  "Безразмерная - Remastered"
# --- Найден трек  "Детский мир - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Детский мир - Remastered"
# --- Аудио фичи для трека "Полюса" - "Детский мир - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Детский мир - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Детский мир - Remastered" добавлена
# --- Добавлен трек  "Детский мир - Remastered"
# --- Найден трек  "Анатолий - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Анатолий - Remastered"
# --- Аудио фичи для трека "Полюса" - "Анатолий - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Анатолий - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Анатолий - Remastered" добавлена
# --- Добавлен трек  "Анатолий - Remastered"
# --- Найден трек  "В круге света - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "В круге света - Remastered"
# --- Аудио фичи для трека "Полюса" - "В круге света - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "В круге света - Remastered"
# --- Информация о прослушиваниях "Полюса" - "В круге света - Remastered" добавлена
# --- Добавлен трек  "В круге света - Remastered"
# --- Найден трек  "Северная сказка - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Северная сказка - Remastered"
# --- Аудио фичи для трека "Полюса" - "Северная сказка - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Северная сказка - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Северная сказка - Remastered" добавлена
# --- Добавлен трек  "Северная сказка - Remastered"
# --- Найден трек  "Дым - Remastered"
# --- Поиск аудио фичей для трека "Полюса" - "Дым - Remastered"
# --- Аудио фичи для трека "Полюса" - "Дым - Remastered" найдены
# --- Поиск информации о прослушиваниях "Полюса" - "Дым - Remastered"
# --- Информация о прослушиваниях "Полюса" - "Дым - Remastered" добавлена
# --- Добавлен трек  "Дым - Remastered"
# Поиск треков из 2061 альбома "Элизиум" - "Жыве Беларусь"
# --- Найден трек  "Жыве Беларусь"
# --- Поиск аудио фичей для трека "Элизиум" - "Жыве Беларусь"
# --- Аудио фичи для трека "Элизиум" - "Жыве Беларусь" найдены
# --- Поиск информации о прослушиваниях "Элизиум" - "Жыве Беларусь"
# --- Информация о прослушиваниях "Элизиум" - "Жыве Беларусь" добавлена
# --- Добавлен трек  "Жыве Беларусь"
# Поиск треков из 2062 альбома "Кис-Кис" - "личка"
# --- Найден трек  "личка"
# --- Поиск аудио фичей для трека "Кис-Кис" - "личка"
# --- Аудио фичи для трека "Кис-Кис" - "личка" найдены
# --- Поиск информации о прослушиваниях "Кис-Кис" - "личка"
# --- Информация о прослушиваниях "Кис-Кис" - "личка" добавлена
# --- Добавлен трек  "личка"
# Поиск треков из 2063 альбома "Артур Беркут" - "Трибьют Сектор Газа"
# --- Найден трек  "Возле дома твоего"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Возле дома твоего"
# --- Аудио фичи для трека "Артур Беркут" - "Возле дома твоего" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Возле дома твоего"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Возле дома твоего" не найдена
# --- Добавлен трек  "Возле дома твоего"
# --- Найден трек  "Колхозный панк"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Колхозный панк"
# --- Аудио фичи для трека "Артур Беркут" - "Колхозный панк" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Колхозный панк"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Колхозный панк" не найдена
# --- Добавлен трек  "Колхозный панк"
# --- Найден трек  "Утопленник"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Утопленник"
# --- Аудио фичи для трека "Артур Беркут" - "Утопленник" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Утопленник"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Утопленник" не найдена
# --- Добавлен трек  "Утопленник"
# --- Найден трек  "Ночь перед Рождеством"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Ночь перед Рождеством"
# --- Аудио фичи для трека "Артур Беркут" - "Ночь перед Рождеством" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Ночь перед Рождеством"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Ночь перед Рождеством" не найдена
# --- Добавлен трек  "Ночь перед Рождеством"
# --- Найден трек  "Нас ждут из темноты"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Нас ждут из темноты"
# --- Аудио фичи для трека "Артур Беркут" - "Нас ждут из темноты" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Нас ждут из темноты"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Нас ждут из темноты" не найдена
# --- Добавлен трек  "Нас ждут из темноты"
# --- Найден трек  "Хорошо в деревне летом"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Хорошо в деревне летом"
# --- Аудио фичи для трека "Артур Беркут" - "Хорошо в деревне летом" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Хорошо в деревне летом"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Хорошо в деревне летом" не найдена
# --- Добавлен трек  "Хорошо в деревне летом"
# --- Найден трек  "Твой звонок"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Твой звонок"
# --- Аудио фичи для трека "Артур Беркут" - "Твой звонок" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Твой звонок"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Твой звонок" не найдена
# --- Добавлен трек  "Твой звонок"
# --- Найден трек  "Казачья"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Казачья"
# --- Аудио фичи для трека "Артур Беркут" - "Казачья" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Казачья"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Казачья" не найдена
# --- Добавлен трек  "Казачья"
# --- Найден трек  "Укус вампира"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Укус вампира"
# --- Аудио фичи для трека "Артур Беркут" - "Укус вампира" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Укус вампира"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Укус вампира" не найдена
# --- Добавлен трек  "Укус вампира"
# --- Найден трек  "Кума"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Кума"
# --- Аудио фичи для трека "Артур Беркут" - "Кума" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Кума"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Кума" не найдена
# --- Добавлен трек  "Кума"
# --- Найден трек  "Свидание"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Свидание"
# --- Аудио фичи для трека "Артур Беркут" - "Свидание" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Свидание"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Свидание" не найдена
# --- Добавлен трек  "Свидание"
# --- Найден трек  "Туман"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Туман"
# --- Аудио фичи для трека "Артур Беркут" - "Туман" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Туман"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Туман" не найдена
# --- Добавлен трек  "Туман"
# --- Найден трек  "Авто-мат"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Авто-мат"
# --- Аудио фичи для трека "Артур Беркут" - "Авто-мат" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Авто-мат"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Авто-мат" не найдена
# --- Добавлен трек  "Авто-мат"
# --- Найден трек  "Святая война (feat. Чёрный Вторник)"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Святая война (feat. Чёрный Вторник)"
# --- Аудио фичи для трека "Артур Беркут" - "Святая война (feat. Чёрный Вторник)" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Святая война (feat. Чёрный Вторник)"
# --- Информация о прослушиваниях "Артур Беркут" - "Святая война (feat. Чёрный Вторник)" добавлена
# --- Добавлен трек  "Святая война (feat. Чёрный Вторник)"
# --- Найден трек  "Лирика"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Лирика"
# --- Аудио фичи для трека "Артур Беркут" - "Лирика" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Лирика"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Лирика" не найдена
# --- Добавлен трек  "Лирика"
# --- Найден трек  "Аванс"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Аванс"
# --- Аудио фичи для трека "Артур Беркут" - "Аванс" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Аванс"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Аванс" не найдена
# --- Добавлен трек  "Аванс"
# --- Найден трек  "Life"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Life"
# --- Аудио фичи для трека "Артур Беркут" - "Life" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Life"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Life" не найдена
# --- Добавлен трек  "Life"
# --- Найден трек  "Хата (feat. Ирина Клинских)"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Хата (feat. Ирина Клинских)"
# --- Аудио фичи для трека "Артур Беркут" - "Хата (feat. Ирина Клинских)" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Хата (feat. Ирина Клинских)"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Хата (feat. Ирина Клинских)" не найдена
# --- Добавлен трек  "Хата (feat. Ирина Клинских)"
# --- Найден трек  "Самые лучшие тачки"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Самые лучшие тачки"
# --- Аудио фичи для трека "Артур Беркут" - "Самые лучшие тачки" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Самые лучшие тачки"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Самые лучшие тачки" не найдена
# --- Добавлен трек  "Самые лучшие тачки"
# --- Найден трек  "Опарыш"
# --- Поиск аудио фичей для трека "Артур Беркут" - "Опарыш"
# --- Аудио фичи для трека "Артур Беркут" - "Опарыш" найдены
# --- Поиск информации о прослушиваниях "Артур Беркут" - "Опарыш"
# --- !!! Информация о прослушиваниях "Артур Беркут" - "Опарыш" не найдена
# --- Добавлен трек  "Опарыш"
# Поиск треков из 2064 альбома "Последние танки в Париже" - "Ультиматум"
# --- Найден трек  "Ситуация"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Ситуация"
# --- Аудио фичи для трека "Последние танки в Париже" - "Ситуация" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Ситуация"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Ситуация" добавлена
# --- Добавлен трек  "Ситуация"
# --- Найден трек  "Жизнь за царя"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Жизнь за царя"
# --- Аудио фичи для трека "Последние танки в Париже" - "Жизнь за царя" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Жизнь за царя"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Жизнь за царя" добавлена
# --- Добавлен трек  "Жизнь за царя"
# --- Найден трек  "Всё позволено"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Всё позволено"
# --- Аудио фичи для трека "Последние танки в Париже" - "Всё позволено" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Всё позволено"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Всё позволено" добавлена
# --- Добавлен трек  "Всё позволено"
# --- Найден трек  "Смерть в кредит"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Смерть в кредит"
# --- Аудио фичи для трека "Последние танки в Париже" - "Смерть в кредит" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Смерть в кредит"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Смерть в кредит" добавлена
# --- Добавлен трек  "Смерть в кредит"
# --- Найден трек  "Война"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Война"
# --- Аудио фичи для трека "Последние танки в Париже" - "Война" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Война"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Война" добавлена
# --- Добавлен трек  "Война"
# --- Найден трек  "Что делать"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Что делать"
# --- Аудио фичи для трека "Последние танки в Париже" - "Что делать" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Что делать"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Что делать" добавлена
# --- Добавлен трек  "Что делать"
# --- Найден трек  "Стукач"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Стукач"
# --- Аудио фичи для трека "Последние танки в Париже" - "Стукач" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Стукач"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Стукач" добавлена
# --- Добавлен трек  "Стукач"
# --- Найден трек  "Ультиматум"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Ультиматум"
# --- Аудио фичи для трека "Последние танки в Париже" - "Ультиматум" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Ультиматум"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Ультиматум" добавлена
# --- Добавлен трек  "Ультиматум"
# --- Найден трек  "Третий отдел"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Третий отдел"
# --- Аудио фичи для трека "Последние танки в Париже" - "Третий отдел" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Третий отдел"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Третий отдел" добавлена
# --- Добавлен трек  "Третий отдел"
# --- Найден трек  "Ночь длинных ножей"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Ночь длинных ножей"
# --- Аудио фичи для трека "Последние танки в Париже" - "Ночь длинных ножей" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Ночь длинных ножей"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Ночь длинных ножей" добавлена
# --- Добавлен трек  "Ночь длинных ножей"
# --- Найден трек  "Трава и таблетки"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Трава и таблетки"
# --- Аудио фичи для трека "Последние танки в Париже" - "Трава и таблетки" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Трава и таблетки"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Трава и таблетки" добавлена
# --- Добавлен трек  "Трава и таблетки"
# --- Найден трек  "Андеграунд"
# --- Поиск аудио фичей для трека "Последние танки в Париже" - "Андеграунд"
# --- Аудио фичи для трека "Последние танки в Париже" - "Андеграунд" найдены
# --- Поиск информации о прослушиваниях "Последние танки в Париже" - "Андеграунд"
# --- Информация о прослушиваниях "Последние танки в Париже" - "Андеграунд" добавлена
# --- Добавлен трек  "Андеграунд"
# Поиск треков из 2065 альбома "Grizzly Knows No Remorse" - "Fat Glasses and the Leather Mustache"
# --- Найден трек  "What It Takes and How It Tastes"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "What It Takes and How It Tastes"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "What It Takes and How It Tastes" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "What It Takes and How It Tastes"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "What It Takes and How It Tastes" добавлена
# --- Добавлен трек  "What It Takes and How It Tastes"
# --- Найден трек  "We Are the Party"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "We Are the Party"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "We Are the Party" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "We Are the Party"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "We Are the Party" добавлена
# --- Добавлен трек  "We Are the Party"
# --- Найден трек  "Good Guys Cum Twice"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "Good Guys Cum Twice"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "Good Guys Cum Twice" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "Good Guys Cum Twice"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "Good Guys Cum Twice" добавлена
# --- Добавлен трек  "Good Guys Cum Twice"
# --- Найден трек  "Equalising Mourning"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "Equalising Mourning"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "Equalising Mourning" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "Equalising Mourning"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "Equalising Mourning" добавлена
# --- Добавлен трек  "Equalising Mourning"
# --- Найден трек  "Godstasy"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "Godstasy"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "Godstasy" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "Godstasy"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "Godstasy" добавлена
# --- Добавлен трек  "Godstasy"
# --- Найден трек  "Waiting to Be"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "Waiting to Be"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "Waiting to Be" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "Waiting to Be"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "Waiting to Be" добавлена
# --- Добавлен трек  "Waiting to Be"
# --- Найден трек  "Refuse, Despise"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "Refuse, Despise"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "Refuse, Despise" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "Refuse, Despise"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "Refuse, Despise" добавлена
# --- Добавлен трек  "Refuse, Despise"
# --- Найден трек  "The Hangover Anthem"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "The Hangover Anthem"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "The Hangover Anthem" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "The Hangover Anthem"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "The Hangover Anthem" добавлена
# --- Добавлен трек  "The Hangover Anthem"
# --- Найден трек  "Glory Hole"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "Glory Hole"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "Glory Hole" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "Glory Hole"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "Glory Hole" добавлена
# --- Добавлен трек  "Glory Hole"
# --- Найден трек  "Wasted Prophet"
# --- Поиск аудио фичей для трека "Grizzly Knows No Remorse" - "Wasted Prophet"
# --- Аудио фичи для трека "Grizzly Knows No Remorse" - "Wasted Prophet" найдены
# --- Поиск информации о прослушиваниях "Grizzly Knows No Remorse" - "Wasted Prophet"
# --- Информация о прослушиваниях "Grizzly Knows No Remorse" - "Wasted Prophet" добавлена
# --- Добавлен трек  "Wasted Prophet"
# Поиск треков из 2066 альбома "Цветы" - "Жить без тебя"
# --- Найден трек  "Жить без тебя"
# --- Поиск аудио фичей для трека "Цветы" - "Жить без тебя"
# --- Аудио фичи для трека "Цветы" - "Жить без тебя" найдены
# --- Поиск информации о прослушиваниях "Цветы" - "Жить без тебя"
# --- Информация о прослушиваниях "Цветы" - "Жить без тебя" добавлена
# --- Добавлен трек  "Жить без тебя"
# --- Найден трек  "Стучат колёса"
# --- Поиск аудио фичей для трека "Цветы" - "Стучат колёса"
# --- Аудио фичи для трека "Цветы" - "Стучат колёса" найдены
# --- Поиск информации о прослушиваниях "Цветы" - "Стучат колёса"
# --- Информация о прослушиваниях "Цветы" - "Стучат колёса" добавлена
# --- Добавлен трек  "Стучат колёса"
# --- Найден трек  "Она была"
# --- Поиск аудио фичей для трека "Цветы" - "Она была"
# --- Аудио фичи для трека "Цветы" - "Она была" найдены
# --- Поиск информации о прослушиваниях "Цветы" - "Она была"
# --- Информация о прослушиваниях "Цветы" - "Она была" добавлена
# --- Добавлен трек  "Она была"
# Поиск треков из 2067 альбома "Кооператив Ништяк" - "Что наверху, то и внизу"
# --- Найден трек  "Дым"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Дым"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Дым" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Дым"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Дым" добавлена
# --- Добавлен трек  "Дым"
# --- Найден трек  "Персы"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Персы"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Персы" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Персы"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Персы" добавлена
# --- Добавлен трек  "Персы"
# --- Найден трек  "Брокэн"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Брокэн"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Брокэн" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Брокэн"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Брокэн" добавлена
# --- Добавлен трек  "Брокэн"
# --- Найден трек  "Мрамор"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Мрамор"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Мрамор" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Мрамор"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Мрамор" добавлена
# --- Добавлен трек  "Мрамор"
# --- Найден трек  "Моцарт"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Моцарт"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Моцарт" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Моцарт"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Моцарт" добавлена
# --- Добавлен трек  "Моцарт"
# --- Найден трек  "Абстракция"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Абстракция"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Абстракция" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Абстракция"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Абстракция" добавлена
# --- Добавлен трек  "Абстракция"
# --- Найден трек  "Пара-бара-бум"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Пара-бара-бум"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Пара-бара-бум" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Пара-бара-бум"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Пара-бара-бум" добавлена
# --- Добавлен трек  "Пара-бара-бум"
# --- Найден трек  "Адольф"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Адольф"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Адольф" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Адольф"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Адольф" добавлена
# --- Добавлен трек  "Адольф"
# --- Найден трек  "Бухенвальд"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Бухенвальд"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Бухенвальд" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Бухенвальд"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Бухенвальд" добавлена
# --- Добавлен трек  "Бухенвальд"
# --- Найден трек  "Тоска"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Тоска"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Тоска" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Тоска"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Тоска" добавлена
# --- Добавлен трек  "Тоска"
# --- Найден трек  "Амон-ра"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Амон-ра"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Амон-ра" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Амон-ра"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Амон-ра" добавлена
# --- Добавлен трек  "Амон-ра"
# --- Найден трек  "Дом"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Дом"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Дом" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Дом"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Дом" добавлена
# --- Добавлен трек  "Дом"
# --- Найден трек  "Луна"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Луна"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Луна" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Луна"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Луна" добавлена
# --- Добавлен трек  "Луна"
# --- Найден трек  "Небо"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Небо"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Небо" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Небо"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Небо" добавлена
# --- Добавлен трек  "Небо"
# --- Найден трек  "Вера"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Вера"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Вера" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Вера"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Вера" добавлена
# --- Добавлен трек  "Вера"
# --- Найден трек  "Зима"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Зима"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Зима" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Зима"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Зима" добавлена
# --- Добавлен трек  "Зима"
# --- Найден трек  "Ветер"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Ветер"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Ветер" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Ветер"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Ветер" добавлена
# --- Добавлен трек  "Ветер"
# --- Найден трек  "Шлем Мамбрина"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Шлем Мамбрина"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Шлем Мамбрина" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Шлем Мамбрина"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Шлем Мамбрина" добавлена
# --- Добавлен трек  "Шлем Мамбрина"
# --- Найден трек  "Гроб"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Гроб"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Гроб" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Гроб"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Гроб" добавлена
# --- Добавлен трек  "Гроб"
# --- Найден трек  "Свастика"
# --- Поиск аудио фичей для трека "Кооператив Ништяк" - "Свастика"
# --- Аудио фичи для трека "Кооператив Ништяк" - "Свастика" найдены
# --- Поиск информации о прослушиваниях "Кооператив Ништяк" - "Свастика"
# --- Информация о прослушиваниях "Кооператив Ништяк" - "Свастика" добавлена
# --- Добавлен трек  "Свастика"
# Поиск треков из 2068 альбома "Машина времени" - "Часы и Знаки"
# --- Найден трек  "Эпоха Большой Нелюбви"
# --- Поиск аудио фичей для трека "Машина времени" - "Эпоха Большой Нелюбви"
# --- Аудио фичи для трека "Машина времени" - "Эпоха Большой Нелюбви" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Эпоха Большой Нелюбви"
# --- Информация о прослушиваниях "Машина времени" - "Эпоха Большой Нелюбви" добавлена
# --- Добавлен трек  "Эпоха Большой Нелюбви"
# --- Найден трек  "Странные Дни"
# --- Поиск аудио фичей для трека "Машина времени" - "Странные Дни"
# --- Аудио фичи для трека "Машина времени" - "Странные Дни" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Странные Дни"
# --- Информация о прослушиваниях "Машина времени" - "Странные Дни" добавлена
# --- Добавлен трек  "Странные Дни"
# --- Найден трек  "Домажо"
# --- Поиск аудио фичей для трека "Машина времени" - "Домажо"
# --- Аудио фичи для трека "Машина времени" - "Домажо" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Домажо"
# --- Информация о прослушиваниях "Машина времени" - "Домажо" добавлена
# --- Добавлен трек  "Домажо"
# --- Найден трек  "Дай Мне Руку, Душа Моя"
# --- Поиск аудио фичей для трека "Машина времени" - "Дай Мне Руку, Душа Моя"
# --- Аудио фичи для трека "Машина времени" - "Дай Мне Руку, Душа Моя" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Дай Мне Руку, Душа Моя"
# --- Информация о прослушиваниях "Машина времени" - "Дай Мне Руку, Душа Моя" добавлена
# --- Добавлен трек  "Дай Мне Руку, Душа Моя"
# --- Найден трек  "Когда Мы Сойдем с Ума"
# --- Поиск аудио фичей для трека "Машина времени" - "Когда Мы Сойдем с Ума"
# --- Аудио фичи для трека "Машина времени" - "Когда Мы Сойдем с Ума" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Когда Мы Сойдем с Ума"
# --- Информация о прослушиваниях "Машина времени" - "Когда Мы Сойдем с Ума" добавлена
# --- Добавлен трек  "Когда Мы Сойдем с Ума"
# --- Найден трек  "Лифт"
# --- Поиск аудио фичей для трека "Машина времени" - "Лифт"
# --- Аудио фичи для трека "Машина времени" - "Лифт" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Лифт"
# --- Информация о прослушиваниях "Машина времени" - "Лифт" добавлена
# --- Добавлен трек  "Лифт"
# --- Найден трек  "Я Так Устал на Войне"
# --- Поиск аудио фичей для трека "Машина времени" - "Я Так Устал на Войне"
# --- Аудио фичи для трека "Машина времени" - "Я Так Устал на Войне" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Я Так Устал на Войне"
# --- Информация о прослушиваниях "Машина времени" - "Я Так Устал на Войне" добавлена
# --- Добавлен трек  "Я Так Устал на Войне"
# --- Найден трек  "Не Плачь обо Мне"
# --- Поиск аудио фичей для трека "Машина времени" - "Не Плачь обо Мне"
# --- Аудио фичи для трека "Машина времени" - "Не Плачь обо Мне" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Не Плачь обо Мне"
# --- Информация о прослушиваниях "Машина времени" - "Не Плачь обо Мне" добавлена
# --- Добавлен трек  "Не Плачь обо Мне"
# --- Найден трек  "На Абрикосовых Холмах"
# --- Поиск аудио фичей для трека "Машина времени" - "На Абрикосовых Холмах"
# --- Аудио фичи для трека "Машина времени" - "На Абрикосовых Холмах" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "На Абрикосовых Холмах"
# --- Информация о прослушиваниях "Машина времени" - "На Абрикосовых Холмах" добавлена
# --- Добавлен трек  "На Абрикосовых Холмах"
# --- Найден трек  "Из Гельминтов"
# --- Поиск аудио фичей для трека "Машина времени" - "Из Гельминтов"
# --- Аудио фичи для трека "Машина времени" - "Из Гельминтов" найдены
# --- Поиск информации о прослушиваниях "Машина времени" - "Из Гельминтов"
# --- Информация о прослушиваниях "Машина времени" - "Из Гельминтов" добавлена
# --- Добавлен трек  "Из Гельминтов"
# Поиск треков из 2069 альбома "Кукрыниксы" - "Столкновение"
# --- Найден трек  "Серебряный сентябрь"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Серебряный сентябрь"
# --- Аудио фичи для трека "Кукрыниксы" - "Серебряный сентябрь" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Серебряный сентябрь"
# --- Информация о прослушиваниях "Кукрыниксы" - "Серебряный сентябрь" добавлена
# --- Добавлен трек  "Серебряный сентябрь"
# --- Найден трек  "Знай"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Знай"
# --- Аудио фичи для трека "Кукрыниксы" - "Знай" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Знай"
# --- Информация о прослушиваниях "Кукрыниксы" - "Знай" добавлена
# --- Добавлен трек  "Знай"
# --- Найден трек  "Параллели"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Параллели"
# --- Аудио фичи для трека "Кукрыниксы" - "Параллели" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Параллели"
# --- Информация о прослушиваниях "Кукрыниксы" - "Параллели" добавлена
# --- Добавлен трек  "Параллели"
# --- Найден трек  "Чёрная невеста"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Чёрная невеста"
# --- Аудио фичи для трека "Кукрыниксы" - "Чёрная невеста" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Чёрная невеста"
# --- Информация о прослушиваниях "Кукрыниксы" - "Чёрная невеста" добавлена
# --- Добавлен трек  "Чёрная невеста"
# --- Найден трек  "Движение"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Движение"
# --- Аудио фичи для трека "Кукрыниксы" - "Движение" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Движение"
# --- Информация о прослушиваниях "Кукрыниксы" - "Движение" добавлена
# --- Добавлен трек  "Движение"
# --- Найден трек  "Последнее письмо"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Последнее письмо"
# --- Аудио фичи для трека "Кукрыниксы" - "Последнее письмо" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Последнее письмо"
# --- Информация о прослушиваниях "Кукрыниксы" - "Последнее письмо" добавлена
# --- Добавлен трек  "Последнее письмо"
# --- Найден трек  "Чучело (привет КиШ)"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Чучело (привет КиШ)"
# --- Аудио фичи для трека "Кукрыниксы" - "Чучело (привет КиШ)" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Чучело (привет КиШ)"
# --- Информация о прослушиваниях "Кукрыниксы" - "Чучело (привет КиШ)" добавлена
# --- Добавлен трек  "Чучело (привет КиШ)"
# --- Найден трек  "Ясные дни"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Ясные дни"
# --- Аудио фичи для трека "Кукрыниксы" - "Ясные дни" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Ясные дни"
# --- Информация о прослушиваниях "Кукрыниксы" - "Ясные дни" добавлена
# --- Добавлен трек  "Ясные дни"
# --- Найден трек  "Время"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Время"
# --- Аудио фичи для трека "Кукрыниксы" - "Время" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Время"
# --- Информация о прослушиваниях "Кукрыниксы" - "Время" добавлена
# --- Добавлен трек  "Время"
# --- Найден трек  "Этот белый свет"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Этот белый свет"
# --- Аудио фичи для трека "Кукрыниксы" - "Этот белый свет" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Этот белый свет"
# --- Информация о прослушиваниях "Кукрыниксы" - "Этот белый свет" добавлена
# --- Добавлен трек  "Этот белый свет"
# --- Найден трек  "9-я рота"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "9-я рота"
# --- Аудио фичи для трека "Кукрыниксы" - "9-я рота" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "9-я рота"
# --- Информация о прослушиваниях "Кукрыниксы" - "9-я рота" добавлена
# --- Добавлен трек  "9-я рота"
# --- Найден трек  "Столкновение"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Столкновение"
# --- Аудио фичи для трека "Кукрыниксы" - "Столкновение" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Столкновение"
# --- Информация о прослушиваниях "Кукрыниксы" - "Столкновение" добавлена
# --- Добавлен трек  "Столкновение"
# --- Найден трек  "Твои счастливые глаза"
# --- Поиск аудио фичей для трека "Кукрыниксы" - "Твои счастливые глаза"
# --- Аудио фичи для трека "Кукрыниксы" - "Твои счастливые глаза" найдены
# --- Поиск информации о прослушиваниях "Кукрыниксы" - "Твои счастливые глаза"
# --- Информация о прослушиваниях "Кукрыниксы" - "Твои счастливые глаза" добавлена
# --- Добавлен трек  "Твои счастливые глаза"
# Поиск треков из 2070 альбома "Обе-Рек" - "Всякий раз..."
# --- Найден трек  "Всякий раз..."
# --- Поиск аудио фичей для трека "Обе-Рек" - "Всякий раз..."
# --- Аудио фичи для трека "Обе-Рек" - "Всякий раз..." найдены
# --- Поиск информации о прослушиваниях "Обе-Рек" - "Всякий раз..."
# --- Информация о прослушиваниях "Обе-Рек" - "Всякий раз..." добавлена
# --- Добавлен трек  "Всякий раз..."
# --- Найден трек  "К ветру успеть"
# --- Поиск аудио фичей для трека "Обе-Рек" - "К ветру успеть"
# --- Аудио фичи для трека "Обе-Рек" - "К ветру успеть" найдены
# --- Поиск информации о прослушиваниях "Обе-Рек" - "К ветру успеть"
# --- Информация о прослушиваниях "Обе-Рек" - "К ветру успеть" добавлена
# --- Добавлен трек  "К ветру успеть"
# Поиск треков из 2071 альбома "Pussy Riot" - "1937"
# --- Найден трек  "1937"
# --- Поиск аудио фичей для трека "Pussy Riot" - "1937"
# --- Аудио фичи для трека "Pussy Riot" - "1937" найдены
# --- Поиск информации о прослушиваниях "Pussy Riot" - "1937"
# --- Информация о прослушиваниях "Pussy Riot" - "1937" добавлена
# --- Добавлен трек  "1937"
# Поиск треков из 2072 альбома "Настя" - "НеНастье"
# --- Найден трек  "Время летит"
# --- Поиск аудио фичей для трека "Настя" - "Время летит"
# --- Аудио фичи для трека "Настя" - "Время летит" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Время летит"
# --- Информация о прослушиваниях "Настя" - "Время летит" добавлена
# --- Добавлен трек  "Время летит"
# --- Найден трек  "Войны"
# --- Поиск аудио фичей для трека "Настя" - "Войны"
# --- Аудио фичи для трека "Настя" - "Войны" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Войны"
# --- Информация о прослушиваниях "Настя" - "Войны" добавлена
# --- Добавлен трек  "Войны"
# --- Найден трек  "У нас нет песни"
# --- Поиск аудио фичей для трека "Настя" - "У нас нет песни"
# --- Аудио фичи для трека "Настя" - "У нас нет песни" найдены
# --- Поиск информации о прослушиваниях "Настя" - "У нас нет песни"
# --- Информация о прослушиваниях "Настя" - "У нас нет песни" добавлена
# --- Добавлен трек  "У нас нет песни"
# --- Найден трек  "Рабочая река"
# --- Поиск аудио фичей для трека "Настя" - "Рабочая река"
# --- Аудио фичи для трека "Настя" - "Рабочая река" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Рабочая река"
# --- Информация о прослушиваниях "Настя" - "Рабочая река" добавлена
# --- Добавлен трек  "Рабочая река"
# --- Найден трек  "Опоздала луна"
# --- Поиск аудио фичей для трека "Настя" - "Опоздала луна"
# --- Аудио фичи для трека "Настя" - "Опоздала луна" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Опоздала луна"
# --- Информация о прослушиваниях "Настя" - "Опоздала луна" добавлена
# --- Добавлен трек  "Опоздала луна"
# --- Найден трек  "Большой огонь"
# --- Поиск аудио фичей для трека "Настя" - "Большой огонь"
# --- Аудио фичи для трека "Настя" - "Большой огонь" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Большой огонь"
# --- Информация о прослушиваниях "Настя" - "Большой огонь" добавлена
# --- Добавлен трек  "Большой огонь"
# --- Найден трек  "Иду себе"
# --- Поиск аудио фичей для трека "Настя" - "Иду себе"
# --- Аудио фичи для трека "Настя" - "Иду себе" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Иду себе"
# --- Информация о прослушиваниях "Настя" - "Иду себе" добавлена
# --- Добавлен трек  "Иду себе"
# --- Найден трек  "Кино"
# --- Поиск аудио фичей для трека "Настя" - "Кино"
# --- Аудио фичи для трека "Настя" - "Кино" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Кино"
# --- Информация о прослушиваниях "Настя" - "Кино" добавлена
# --- Добавлен трек  "Кино"
# --- Найден трек  "Факультет естественной любви"
# --- Поиск аудио фичей для трека "Настя" - "Факультет естественной любви"
# --- Аудио фичи для трека "Настя" - "Факультет естественной любви" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Факультет естественной любви"
# --- Информация о прослушиваниях "Настя" - "Факультет естественной любви" добавлена
# --- Добавлен трек  "Факультет естественной любви"
# --- Найден трек  "Следи за небом"
# --- Поиск аудио фичей для трека "Настя" - "Следи за небом"
# --- Аудио фичи для трека "Настя" - "Следи за небом" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Следи за небом"
# --- Информация о прослушиваниях "Настя" - "Следи за небом" добавлена
# --- Добавлен трек  "Следи за небом"
# --- Найден трек  "Факультет естественной любви - Dub Remix"
# --- Поиск аудио фичей для трека "Настя" - "Факультет естественной любви - Dub Remix"
# --- Аудио фичи для трека "Настя" - "Факультет естественной любви - Dub Remix" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Факультет естественной любви - Dub Remix"
# --- Информация о прослушиваниях "Настя" - "Факультет естественной любви - Dub Remix" добавлена
# --- Добавлен трек  "Факультет естественной любви - Dub Remix"
# --- Найден трек  "Факультет естественной любви - Ragga Remix"
# --- Поиск аудио фичей для трека "Настя" - "Факультет естественной любви - Ragga Remix"
# --- Аудио фичи для трека "Настя" - "Факультет естественной любви - Ragga Remix" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Факультет естественной любви - Ragga Remix"
# --- Информация о прослушиваниях "Настя" - "Факультет естественной любви - Ragga Remix" добавлена
# --- Добавлен трек  "Факультет естественной любви - Ragga Remix"
# Поиск треков из 2073 альбома "Пасош" - "Снова возвращаюсь домой"
# --- Найден трек  "Все не так"
# --- Поиск аудио фичей для трека "Пасош" - "Все не так"
# --- Аудио фичи для трека "Пасош" - "Все не так" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Все не так"
# --- Информация о прослушиваниях "Пасош" - "Все не так" добавлена
# --- Добавлен трек  "Все не так"
# --- Найден трек  "Твои слова"
# --- Поиск аудио фичей для трека "Пасош" - "Твои слова"
# --- Аудио фичи для трека "Пасош" - "Твои слова" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Твои слова"
# --- Информация о прослушиваниях "Пасош" - "Твои слова" добавлена
# --- Добавлен трек  "Твои слова"
# --- Найден трек  "Больше не вернуть"
# --- Поиск аудио фичей для трека "Пасош" - "Больше не вернуть"
# --- Аудио фичи для трека "Пасош" - "Больше не вернуть" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Больше не вернуть"
# --- Информация о прослушиваниях "Пасош" - "Больше не вернуть" добавлена
# --- Добавлен трек  "Больше не вернуть"
# --- Найден трек  "Искать себя"
# --- Поиск аудио фичей для трека "Пасош" - "Искать себя"
# --- Аудио фичи для трека "Пасош" - "Искать себя" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Искать себя"
# --- Информация о прослушиваниях "Пасош" - "Искать себя" добавлена
# --- Добавлен трек  "Искать себя"
# --- Найден трек  "Стоп-слово"
# --- Поиск аудио фичей для трека "Пасош" - "Стоп-слово"
# --- Аудио фичи для трека "Пасош" - "Стоп-слово" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Стоп-слово"
# --- Информация о прослушиваниях "Пасош" - "Стоп-слово" добавлена
# --- Добавлен трек  "Стоп-слово"
# --- Найден трек  "Ночная смена"
# --- Поиск аудио фичей для трека "Пасош" - "Ночная смена"
# --- Аудио фичи для трека "Пасош" - "Ночная смена" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Ночная смена"
# --- Информация о прослушиваниях "Пасош" - "Ночная смена" добавлена
# --- Добавлен трек  "Ночная смена"
# --- Найден трек  "Несчастный случай"
# --- Поиск аудио фичей для трека "Пасош" - "Несчастный случай"
# --- Аудио фичи для трека "Пасош" - "Несчастный случай" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Несчастный случай"
# --- Информация о прослушиваниях "Пасош" - "Несчастный случай" добавлена
# --- Добавлен трек  "Несчастный случай"
# --- Найден трек  "Снова возвращаюсь домой"
# --- Поиск аудио фичей для трека "Пасош" - "Снова возвращаюсь домой"
# --- Аудио фичи для трека "Пасош" - "Снова возвращаюсь домой" найдены
# --- Поиск информации о прослушиваниях "Пасош" - "Снова возвращаюсь домой"
# --- Информация о прослушиваниях "Пасош" - "Снова возвращаюсь домой" добавлена
# --- Добавлен трек  "Снова возвращаюсь домой"
# Поиск треков из 2074 альбома "Дюна" - "Танцор диско"
# --- Найден трек  "Воздушный змей"
# --- Поиск аудио фичей для трека "Дюна" - "Воздушный змей"
# --- Аудио фичи для трека "Дюна" - "Воздушный змей" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Воздушный змей"
# --- Информация о прослушиваниях "Дюна" - "Воздушный змей" добавлена
# --- Добавлен трек  "Воздушный змей"
# --- Найден трек  "Русский ресторан"
# --- Поиск аудио фичей для трека "Дюна" - "Русский ресторан"
# --- Аудио фичи для трека "Дюна" - "Русский ресторан" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Русский ресторан"
# --- Информация о прослушиваниях "Дюна" - "Русский ресторан" добавлена
# --- Добавлен трек  "Русский ресторан"
# --- Найден трек  "Считалка"
# --- Поиск аудио фичей для трека "Дюна" - "Считалка"
# --- Аудио фичи для трека "Дюна" - "Считалка" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Считалка"
# --- Информация о прослушиваниях "Дюна" - "Считалка" добавлена
# --- Добавлен трек  "Считалка"
# --- Найден трек  "Бандито"
# --- Поиск аудио фичей для трека "Дюна" - "Бандито"
# --- Аудио фичи для трека "Дюна" - "Бандито" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Бандито"
# --- Информация о прослушиваниях "Дюна" - "Бандито" добавлена
# --- Добавлен трек  "Бандито"
# --- Найден трек  "Золотая середина"
# --- Поиск аудио фичей для трека "Дюна" - "Золотая середина"
# --- Аудио фичи для трека "Дюна" - "Золотая середина" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Золотая середина"
# --- Информация о прослушиваниях "Дюна" - "Золотая середина" добавлена
# --- Добавлен трек  "Золотая середина"
# --- Найден трек  "Служебно-розыскная"
# --- Поиск аудио фичей для трека "Дюна" - "Служебно-розыскная"
# --- Аудио фичи для трека "Дюна" - "Служебно-розыскная" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Служебно-розыскная"
# --- Информация о прослушиваниях "Дюна" - "Служебно-розыскная" добавлена
# --- Добавлен трек  "Служебно-розыскная"
# --- Найден трек  "Перья от павлина"
# --- Поиск аудио фичей для трека "Дюна" - "Перья от павлина"
# --- Аудио фичи для трека "Дюна" - "Перья от павлина" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Перья от павлина"
# --- Информация о прослушиваниях "Дюна" - "Перья от павлина" добавлена
# --- Добавлен трек  "Перья от павлина"
# --- Найден трек  "Подойди-поспеши"
# --- Поиск аудио фичей для трека "Дюна" - "Подойди-поспеши"
# --- Аудио фичи для трека "Дюна" - "Подойди-поспеши" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Подойди-поспеши"
# --- Информация о прослушиваниях "Дюна" - "Подойди-поспеши" добавлена
# --- Добавлен трек  "Подойди-поспеши"
# --- Найден трек  "Два дня"
# --- Поиск аудио фичей для трека "Дюна" - "Два дня"
# --- Аудио фичи для трека "Дюна" - "Два дня" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Два дня"
# --- Информация о прослушиваниях "Дюна" - "Два дня" добавлена
# --- Добавлен трек  "Два дня"
# --- Найден трек  "Чи-чи-га"
# --- Поиск аудио фичей для трека "Дюна" - "Чи-чи-га"
# --- Аудио фичи для трека "Дюна" - "Чи-чи-га" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Чи-чи-га"
# --- Информация о прослушиваниях "Дюна" - "Чи-чи-га" добавлена
# --- Добавлен трек  "Чи-чи-га"
# --- Найден трек  "Страна Лимония (Remix)"
# --- Поиск аудио фичей для трека "Дюна" - "Страна Лимония (Remix)"
# --- Аудио фичи для трека "Дюна" - "Страна Лимония (Remix)" найдены
# --- Поиск информации о прослушиваниях "Дюна" - "Страна Лимония (Remix)"
# --- Информация о прослушиваниях "Дюна" - "Страна Лимония (Remix)" добавлена
# ...
# --- Добавлен трек  "Ноа-Ноа"
# --- Найден трек  "Всему свое время - Бонус трек"
# --- Поиск аудио фичей для трека "Настя" - "Всему свое время - Бонус трек"
# --- Аудио фичи для трека "Настя" - "Всему свое время - Бонус трек" найдены
# --- Поиск информации о прослушиваниях "Настя" - "Всему свое время - Бонус трек"
# --- Информация о прослушиваниях "Настя" - "Всему свое время - Бонус трек" добавлена
# --- Добавлен трек  "Всему свое время - Бонус трек"
# Поиск треков из 2581 альбома "Курара" - "Архимед"
# --- Найден трек  "Так оно и будет"
# --- Поиск аудио фичей для трека "Курара" - "Так оно и будет"
# --- Аудио фичи для трека "Курара" - "Так оно и будет" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Так оно и будет"
# --- Информация о прослушиваниях "Курара" - "Так оно и будет" добавлена
# --- Добавлен трек  "Так оно и будет"
# --- Найден трек  "Архимед"
# --- Поиск аудио фичей для трека "Курара" - "Архимед"
# --- Аудио фичи для трека "Курара" - "Архимед" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Архимед"
# --- Информация о прослушиваниях "Курара" - "Архимед" добавлена
# --- Добавлен трек  "Архимед"
# --- Найден трек  "Рокки Rock'n'Roll"
# --- Поиск аудио фичей для трека "Курара" - "Рокки Rock'n'Roll"
# --- Аудио фичи для трека "Курара" - "Рокки Rock'n'Roll" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Рокки Rock'n'Roll"
# --- Информация о прослушиваниях "Курара" - "Рокки Rock'n'Roll" добавлена
# --- Добавлен трек  "Рокки Rock'n'Roll"
# --- Найден трек  "Не моё пальто"
# --- Поиск аудио фичей для трека "Курара" - "Не моё пальто"
# --- Аудио фичи для трека "Курара" - "Не моё пальто" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Не моё пальто"
# --- Информация о прослушиваниях "Курара" - "Не моё пальто" добавлена
# --- Добавлен трек  "Не моё пальто"
# --- Найден трек  "Барокамера"
# --- Поиск аудио фичей для трека "Курара" - "Барокамера"
# --- Аудио фичи для трека "Курара" - "Барокамера" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Барокамера"
# --- Информация о прослушиваниях "Курара" - "Барокамера" добавлена
# --- Добавлен трек  "Барокамера"
# --- Найден трек  "Локомотив"
# --- Поиск аудио фичей для трека "Курара" - "Локомотив"
# --- Аудио фичи для трека "Курара" - "Локомотив" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Локомотив"
# --- Информация о прослушиваниях "Курара" - "Локомотив" добавлена
# --- Добавлен трек  "Локомотив"
# --- Найден трек  "Январь"
# --- Поиск аудио фичей для трека "Курара" - "Январь"
# --- Аудио фичи для трека "Курара" - "Январь" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Январь"
# --- Информация о прослушиваниях "Курара" - "Январь" добавлена
# --- Добавлен трек  "Январь"
# --- Найден трек  "Е-рок"
# --- Поиск аудио фичей для трека "Курара" - "Е-рок"
# --- Аудио фичи для трека "Курара" - "Е-рок" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Е-рок"
# --- Информация о прослушиваниях "Курара" - "Е-рок" добавлена
# --- Добавлен трек  "Е-рок"
# --- Найден трек  "Утро"
# --- Поиск аудио фичей для трека "Курара" - "Утро"
# --- Аудио фичи для трека "Курара" - "Утро" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Утро"
# --- Информация о прослушиваниях "Курара" - "Утро" добавлена
# --- Добавлен трек  "Утро"
# --- Найден трек  "Байконур"
# --- Поиск аудио фичей для трека "Курара" - "Байконур"
# --- Аудио фичи для трека "Курара" - "Байконур" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Байконур"
# --- Информация о прослушиваниях "Курара" - "Байконур" добавлена
# --- Добавлен трек  "Байконур"
# --- Найден трек  "Босоногий пёс - Версия '13"
# --- Поиск аудио фичей для трека "Курара" - "Босоногий пёс - Версия '13"
# --- Аудио фичи для трека "Курара" - "Босоногий пёс - Версия '13" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Босоногий пёс - Версия '13"
# --- Информация о прослушиваниях "Курара" - "Босоногий пёс - Версия '13" добавлена
# --- Добавлен трек  "Босоногий пёс - Версия '13"
# --- Найден трек  "Камни - Версия '13"
# --- Поиск аудио фичей для трека "Курара" - "Камни - Версия '13"
# --- Аудио фичи для трека "Курара" - "Камни - Версия '13" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Камни - Версия '13"
# --- Информация о прослушиваниях "Курара" - "Камни - Версия '13" добавлена
# --- Добавлен трек  "Камни - Версия '13"
# --- Найден трек  "Письмо - Версия '13"
# --- Поиск аудио фичей для трека "Курара" - "Письмо - Версия '13"
# --- Аудио фичи для трека "Курара" - "Письмо - Версия '13" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Письмо - Версия '13"
# --- Информация о прослушиваниях "Курара" - "Письмо - Версия '13" добавлена
# --- Добавлен трек  "Письмо - Версия '13"
# --- Найден трек  "Лётчики - Версия '13"
# --- Поиск аудио фичей для трека "Курара" - "Лётчики - Версия '13"
# --- Аудио фичи для трека "Курара" - "Лётчики - Версия '13" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Лётчики - Версия '13"
# --- Информация о прослушиваниях "Курара" - "Лётчики - Версия '13" добавлена
# --- Добавлен трек  "Лётчики - Версия '13"
# --- Найден трек  "Дерево / Лето - Версия '13"
# --- Поиск аудио фичей для трека "Курара" - "Дерево / Лето - Версия '13"
# --- Аудио фичи для трека "Курара" - "Дерево / Лето - Версия '13" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Дерево / Лето - Версия '13"
# --- Информация о прослушиваниях "Курара" - "Дерево / Лето - Версия '13" добавлена
# --- Добавлен трек  "Дерево / Лето - Версия '13"
# --- Найден трек  "Екатеринбюргер - Версия '13"
# --- Поиск аудио фичей для трека "Курара" - "Екатеринбюргер - Версия '13"
# --- Аудио фичи для трека "Курара" - "Екатеринбюргер - Версия '13" найдены
# --- Поиск информации о прослушиваниях "Курара" - "Екатеринбюргер - Версия '13"
# --- Информация о прослушиваниях "Курара" - "Екатеринбюргер - Версия '13" добавлена
# --- Добавлен трек  "Екатеринбюргер - Версия '13"
# Поиск треков из 2582 альбома "Город 312" - "Конверт"
# --- Найден трек  "Конверт"
# --- Поиск аудио фичей для трека "Город 312" - "Конверт"
# --- Аудио фичи для трека "Город 312" - "Конверт" найдены
# --- Поиск информации о прослушиваниях "Город 312" - "Конверт"
# --- Информация о прослушиваниях "Город 312" - "Конверт" добавлена
# --- Добавлен трек  "Конверт"
# Поиск треков из 2583 альбома "Краснознамённая дивизия имени моей бабушки" - "Танцуй и кайся"
# --- Найден трек  "Танцуй и кайся"
# --- Поиск аудио фичей для трека "Краснознамённая дивизия имени моей бабушки" - "Танцуй и кайся"
# --- Аудио фичи для трека "Краснознамённая дивизия имени моей бабушки" - "Танцуй и кайся" найдены
# --- Поиск информации о прослушиваниях "Краснознамённая дивизия имени моей бабушки" - "Танцуй и кайся"
# --- Информация о прослушиваниях "Краснознамённая дивизия имени моей бабушки" - "Танцуй и кайся" добавлена
# --- Добавлен трек  "Танцуй и кайся"
# Поиск треков из 2584 альбома "Кирпичи" - "Смерть на рэйве"
# --- Найден трек  "Плюю я"
# --- Поиск аудио фичей для трека "Кирпичи" - "Плюю я"
# --- Аудио фичи для трека "Кирпичи" - "Плюю я" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Плюю я"
# --- Информация о прослушиваниях "Кирпичи" - "Плюю я" добавлена
# --- Добавлен трек  "Плюю я"
# --- Найден трек  "Интернет"
# --- Поиск аудио фичей для трека "Кирпичи" - "Интернет"
# --- Аудио фичи для трека "Кирпичи" - "Интернет" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Интернет"
# --- Информация о прослушиваниях "Кирпичи" - "Интернет" добавлена
# --- Добавлен трек  "Интернет"
# --- Найден трек  "Замучили гады"
# --- Поиск аудио фичей для трека "Кирпичи" - "Замучили гады"
# --- Аудио фичи для трека "Кирпичи" - "Замучили гады" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Замучили гады"
# --- Информация о прослушиваниях "Кирпичи" - "Замучили гады" добавлена
# --- Добавлен трек  "Замучили гады"
# --- Найден трек  "Рэп-Кал"
# --- Поиск аудио фичей для трека "Кирпичи" - "Рэп-Кал"
# --- Аудио фичи для трека "Кирпичи" - "Рэп-Кал" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Рэп-Кал"
# --- Информация о прослушиваниях "Кирпичи" - "Рэп-Кал" добавлена
# --- Добавлен трек  "Рэп-Кал"
# --- Найден трек  "Скейтборд"
# --- Поиск аудио фичей для трека "Кирпичи" - "Скейтборд"
# --- Аудио фичи для трека "Кирпичи" - "Скейтборд" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Скейтборд"
# --- Информация о прослушиваниях "Кирпичи" - "Скейтборд" добавлена
# --- Добавлен трек  "Скейтборд"
# --- Найден трек  "Торчи, п., торчи"
# --- Поиск аудио фичей для трека "Кирпичи" - "Торчи, п., торчи"
# --- Аудио фичи для трека "Кирпичи" - "Торчи, п., торчи" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Торчи, п., торчи"
# --- Информация о прослушиваниях "Кирпичи" - "Торчи, п., торчи" добавлена
# --- Добавлен трек  "Торчи, п., торчи"
# --- Найден трек  "В гробу"
# --- Поиск аудио фичей для трека "Кирпичи" - "В гробу"
# --- Аудио фичи для трека "Кирпичи" - "В гробу" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "В гробу"
# --- Информация о прослушиваниях "Кирпичи" - "В гробу" добавлена
# --- Добавлен трек  "В гробу"
# --- Найден трек  "Песня для девочек"
# --- Поиск аудио фичей для трека "Кирпичи" - "Песня для девочек"
# --- Аудио фичи для трека "Кирпичи" - "Песня для девочек" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Песня для девочек"
# --- Информация о прослушиваниях "Кирпичи" - "Песня для девочек" добавлена
# --- Добавлен трек  "Песня для девочек"
# --- Найден трек  "Смысл улыбаться"
# --- Поиск аудио фичей для трека "Кирпичи" - "Смысл улыбаться"
# --- Аудио фичи для трека "Кирпичи" - "Смысл улыбаться" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Смысл улыбаться"
# --- Информация о прослушиваниях "Кирпичи" - "Смысл улыбаться" добавлена
# --- Добавлен трек  "Смысл улыбаться"
# --- Найден трек  "?"
# --- Поиск аудио фичей для трека "Кирпичи" - "?"
# --- Аудио фичи для трека "Кирпичи" - "?" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "?"
# --- Информация о прослушиваниях "Кирпичи" - "?" добавлена
# --- Добавлен трек  "?"
# --- Найден трек  "Слюни на экране"
# --- Поиск аудио фичей для трека "Кирпичи" - "Слюни на экране"
# --- Аудио фичи для трека "Кирпичи" - "Слюни на экране" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Слюни на экране"
# --- Информация о прослушиваниях "Кирпичи" - "Слюни на экране" добавлена
# --- Добавлен трек  "Слюни на экране"
# --- Найден трек  "Песня 13"
# --- Поиск аудио фичей для трека "Кирпичи" - "Песня 13"
# --- Аудио фичи для трека "Кирпичи" - "Песня 13" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Песня 13"
# --- Информация о прослушиваниях "Кирпичи" - "Песня 13" добавлена
# --- Добавлен трек  "Песня 13"
# --- Найден трек  "Я - феминист"
# --- Поиск аудио фичей для трека "Кирпичи" - "Я - феминист"
# --- Аудио фичи для трека "Кирпичи" - "Я - феминист" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Я - феминист"
# --- Информация о прослушиваниях "Кирпичи" - "Я - феминист" добавлена
# --- Добавлен трек  "Я - феминист"
# --- Найден трек  "Шиз-рэп"
# --- Поиск аудио фичей для трека "Кирпичи" - "Шиз-рэп"
# --- Аудио фичи для трека "Кирпичи" - "Шиз-рэп" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Шиз-рэп"
# --- Информация о прослушиваниях "Кирпичи" - "Шиз-рэп" добавлена
# --- Добавлен трек  "Шиз-рэп"
# --- Найден трек  "Смерть на рэйве"
# --- Поиск аудио фичей для трека "Кирпичи" - "Смерть на рэйве"
# --- Аудио фичи для трека "Кирпичи" - "Смерть на рэйве" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Смерть на рэйве"
# --- Информация о прослушиваниях "Кирпичи" - "Смерть на рэйве" добавлена
# --- Добавлен трек  "Смерть на рэйве"
# --- Найден трек  "Задумчивый core"
# --- Поиск аудио фичей для трека "Кирпичи" - "Задумчивый core"
# --- Аудио фичи для трека "Кирпичи" - "Задумчивый core" найдены
# --- Поиск информации о прослушиваниях "Кирпичи" - "Задумчивый core"
# --- Информация о прослушиваниях "Кирпичи" - "Задумчивый core" добавлена
# --- Добавлен трек  "Задумчивый core"
# Поиск треков из 2585 альбома "Башня Rowan" - "Пчеловечность"
# --- Найден трек  "Красный Самайн"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Красный Самайн"
# --- Аудио фичи для трека "Башня Rowan" - "Красный Самайн" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Красный Самайн"
# --- Информация о прослушиваниях "Башня Rowan" - "Красный Самайн" добавлена
# --- Добавлен трек  "Красный Самайн"
# --- Найден трек  "Пчелы"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Пчелы"
# --- Аудио фичи для трека "Башня Rowan" - "Пчелы" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Пчелы"
# --- Информация о прослушиваниях "Башня Rowan" - "Пчелы" добавлена
# --- Добавлен трек  "Пчелы"
# --- Найден трек  "Тэм Лин"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Тэм Лин"
# --- Аудио фичи для трека "Башня Rowan" - "Тэм Лин" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Тэм Лин"
# --- Информация о прослушиваниях "Башня Rowan" - "Тэм Лин" добавлена
# --- Добавлен трек  "Тэм Лин"
# --- Найден трек  "Гейдельбориус"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Гейдельбориус"
# --- Аудио фичи для трека "Башня Rowan" - "Гейдельбориус" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Гейдельбориус"
# --- Информация о прослушиваниях "Башня Rowan" - "Гейдельбориус" добавлена
# --- Добавлен трек  "Гейдельбориус"
# --- Найден трек  "Безумие"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Безумие"
# --- Аудио фичи для трека "Башня Rowan" - "Безумие" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Безумие"
# --- Информация о прослушиваниях "Башня Rowan" - "Безумие" добавлена
# --- Добавлен трек  "Безумие"
# --- Найден трек  "Бледная моль"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Бледная моль"
# --- Аудио фичи для трека "Башня Rowan" - "Бледная моль" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Бледная моль"
# --- Информация о прослушиваниях "Башня Rowan" - "Бледная моль" добавлена
# --- Добавлен трек  "Бледная моль"
# --- Найден трек  "Пчеловечность"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Пчеловечность"
# --- Аудио фичи для трека "Башня Rowan" - "Пчеловечность" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Пчеловечность"
# --- Информация о прослушиваниях "Башня Rowan" - "Пчеловечность" добавлена
# --- Добавлен трек  "Пчеловечность"
# --- Найден трек  "Смешные люди"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Смешные люди"
# --- Аудио фичи для трека "Башня Rowan" - "Смешные люди" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Смешные люди"
# --- Информация о прослушиваниях "Башня Rowan" - "Смешные люди" добавлена
# --- Добавлен трек  "Смешные люди"
# --- Найден трек  "Ангел Катерина"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Ангел Катерина"
# --- Аудио фичи для трека "Башня Rowan" - "Ангел Катерина" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Ангел Катерина"
# --- Информация о прослушиваниях "Башня Rowan" - "Ангел Катерина" добавлена
# --- Добавлен трек  "Ангел Катерина"
# --- Найден трек  "Пчелы-блюз"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Пчелы-блюз"
# --- Аудио фичи для трека "Башня Rowan" - "Пчелы-блюз" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Пчелы-блюз"
# --- Информация о прослушиваниях "Башня Rowan" - "Пчелы-блюз" добавлена
# --- Добавлен трек  "Пчелы-блюз"
# --- Найден трек  "Жаба"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Жаба"
# --- Аудио фичи для трека "Башня Rowan" - "Жаба" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Жаба"
# --- Информация о прослушиваниях "Башня Rowan" - "Жаба" добавлена
# --- Добавлен трек  "Жаба"
# --- Найден трек  "Иголка"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Иголка"
# --- Аудио фичи для трека "Башня Rowan" - "Иголка" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Иголка"
# --- Информация о прослушиваниях "Башня Rowan" - "Иголка" добавлена
# --- Добавлен трек  "Иголка"
# --- Найден трек  "Змей"
# --- Поиск аудио фичей для трека "Башня Rowan" - "Змей"
# --- Аудио фичи для трека "Башня Rowan" - "Змей" найдены
# --- Поиск информации о прослушиваниях "Башня Rowan" - "Змей"
# --- Информация о прослушиваниях "Башня Rowan" - "Змей" добавлена
# --- Добавлен трек  "Змей"
# Добавлено 27032 треков

# %%
# Track.objects.filter(album_id=start).delete()
# Out:
# (6, {'tracks.Track': 6})

# %%
# импорт
from slugify import slugify
from bs4 import BeautifulSoup as bs

# %%
track_list = Track.objects.all().values_list('band_id', 'band_name', 
                                            'album_id', 'album_name',
                                            'track_id', 'track_name') \
                                            .order_by('track_id')[:20]
for track in track_list:
    band_id    = track[0]   # '2GUwb2rxMKePzxDi94EEoZ'
    band_name  = track[1]   # 'Ночные снайперы'
    album_id   = track[2]   # '3z9HvGReqatzDLy2DL1w18'
    album_name = track[3]   # 'Koshika'
    track_id   = track[4]   # '0032CHOcRVH98tHdVYFXRN'
    track_name = track[5]   # 'катастрофически'

    print(band_name, track_name)

    text_dict = { 
        'band_id'    : band_id,
        'band_name'  : band_name,
        'album_id'   : album_id,
        'album_name' : album_name,
        'track_id'   : Track.objects.get(track_id=track_id),
        'track_name' : track_name
    }

    vse_pesni_req  = requests.get(f'https://vse-pesni.com/song/{slugify(band_name)}-{slugify(track_name)}/')
    lyricshare_req = requests.get(f'http://www.lyricshare.net/ru/{slugify(band_name)}/{slugify(track_name)}.html')
    megalyrics_req = requests.get(f'http://www.megalyrics.ru/lyric/{slugify(band_name)}/{slugify(track_name)}.htm')

    if vse_pesni_req.ok:
        vse_pesni_html = bs(vse_pesni_req.text, 'lxml')

        song_text = vse_pesni_html.find('div', id='page') \
                                .find('div', id='main') \
                                .find('div', id='content') \
                                .find('div', class_='entry-content') \
                                .find('div', class_='song_text')

        song_text = (str(song_text.__dict__['contents'][0]) + \
                    str(song_text.__dict__['contents'][2])) \
                    .replace('\n', '')\
                    .replace('\t', '')\
                    .replace('\r', ' ')\
                    .strip()

        song_text_dict = {'song_text': song_text}
        text_dict.update(song_text_dict)
        print(f'Загружен текст с сайта "vse_pesni"')    



    # if vse_pesni_req.ok:
    #     try:
    #         vse_pesni_html = bs(vse_pesni_req.text, 'lxml')

    #         song_text = vse_pesni_html.find('div', id='page') \
    #                                 .find('div', id='main') \
    #                                 .find('div', id='content') \
    #                                 .find('div', class_='entry-content') \
    #                                 .find('div', class_='song_text')
                                    
    #         song_text = str(song_text.__dict__['contents'][0] + \
    #                         song_text.__dict__['contents'][2]) \
    #                         .replace('\n', '') \
    #                         .replace('\t', '') \
    #                         .replace('\r', ' ').strip()

    #         print(song_text)

    #         song_text_dict = {'song_text': song_text}
    #         text_dict.update(**song_text_dict)
    #         print(f'Загружен текст с сайта "vse_pesni"')
    #     except:
    #         pass
            
    # elif lyricshare_req.ok:
    #     try:
    #         lyricshare_req_html = bs(vse_pesni_req.text, 'lxml')

    #         song_text = lyricshare_req_html.find('div', id='page') \
    #                                 .find('div', id='main') \
    #                                 .find('div', id='content') \
    #                                 .find('div', class_='entry-content') \
    #                                 .find('div', class_='song_text')

    #         song_text = song_text.text.replace('ПРИПЕВ', '') \
    #                                 .replace('\n', ' ').strip()

    #         song_text_dict = {'song_text': song_text}
    #         text_dict.update(song_text_dict)
    #         print(f'Загружен текст с сайта "lyricshare"')
    #     except:
    #         pass

    # elif megalyrics_req.ok:
    #     try:
    #         megalyrics_html = bs(megalyrics_req.text, 'lxml')
            
    #         song_text = megalyrics_html.find('div', id='wrap') \
    #                                 .find('div', id='page') \
    #                                 .find('div', id='page_main') \
    #                                 .find('div', id='songs_show') \
    #                                 .find('div', class_='wrap') \
    #                                 .find('div', id='txt') \
    #                                 .find('div', class_='text separate') \
    #                                 .find('div', class_='text_inner')

    #         song_text = str(song_text).replace('<br/>', ' ') \
    #                                 .replace('<div class="text_inner">', '') \
    #                                 .replace('<div id="native_roll">', '') \
    #                                 .replace('</div>', '') \
    #                                 .strip()

    #         song_text_dict = {'song_text': song_text}
    #         text_dict.update(song_text_dict)
    #         print(f'Загружен текст с сайта "megalyrics"')
    #     except:
    #         pass

    # создание записи в БД
    Text.objects.create(**text_dict)

# %%
vse_pesni_req  = requests.get(f'https://vse-pesni.com/song/{band_name}-{track_name}/')
lyricshare_req = requests.get(f'http://www.lyricshare.net/ru/{band_name}/{track_name}.html')
megalyrics_req = requests.get(f'http://www.megalyrics.ru/lyric/{band_name}/{track_name}.htm')

# %%
print(vse_pesni_req.ok, lyricshare_req.ok, megalyrics_req.ok)

# %%
vse_pesni_html = bs(vse_pesni_req.text, 'lxml')

song_text = vse_pesni_html.find('div', id='page') \
                          .find('div', id='main') \
                          .find('div', id='content') \
                          .find('div', class_='entry-content') \
                          .find('div', class_='song_text')

# %%
(song_text.__dict__['contents'][0] + song_text.__dict__['contents'][2]).replace('\n', '').replace('\t', '').replace('\r', ' ').strip()

# %%
lyricshare_html = bs(lyricshare_req.text, 'lxml')

song_text = lyricshare_html.find('div', id='wrapper') \
                           .find('div', class_='wrapper-inner') \
                           .find('div', id='colone-container') \
                           .find('div', class_='col-one') \
                           .find('div', id='textPesniDiv') \
                           .find('div', id='textPesniDiv-outer') \
                           .find('p', id='textpesni')

# %%
song_text.text.replace('ПРИПЕВ', '').replace('\n', ' ').strip()

# %%
track_list = Track.objects.all().values_list('band_id', 'band_name', 
                                            'album_id', 'album_name',
                                            'track_id', 'track_name') \
                                            .order_by('track_id')[:5]

# %%
track_list[3]
# Out:
# ('2GUwb2rxMKePzxDi94EEoZ',
#  'Ночные снайперы',
#  '3z9HvGReqatzDLy2DL1w18',
#  'Koshika',
#  '0032CHOcRVH98tHdVYFXRN',
#  'катастрофически')

# %%
megalyrics_html = bs(megalyrics_req.text, 'lxml')
song_text = megalyrics_html.find('div', id='wrap') \
                           .find('div', id='page') \
                           .find('div', id='page_main') \
                           .find('div', id='songs_show') \
                           .find('div', class_='wrap') \
                           .find('div', id='txt') \
                           .find('div', class_='text separate') \
                           .find('div', class_='text_inner')
print(str(song_text).replace('<br/>', ' ').replace('<div class="text_inner">', '').replace('<div id="native_roll">', '').replace('</div>', '').strip())
